# %% [markdown]
# # Analyzing wildfire activities in Australia

# %% [markdown]
# # Objectives
#
#  - Use visualization libraries such as Matplotlib, Pandas, Seaborn and Folium to create informative plots and charts

# %% [markdown]
# ### Installing Required Libraries

# %%
# %pip install seaborn
# %pip install folium
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# ...
#
#    -------------------- ------------------- 1/2 [folium]
#    -------------------- ------------------- 1/2 [folium]
#    -------------------- ------------------- 1/2 [folium]
#    ---------------------------------------- 2/2 [folium]
#
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ### Importing Required Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import folium
# %matplotlib inline

# %% [markdown]
# # Dataset
#
# **Historical Wildfires**
#
# This wildfire dataset contains data on fire activities in Australia starting from 2005. Additional information can be found [here](https://earthdata.nasa.gov/earth-observation-data/near-real-time/firms/c6-mcd14dl).

# %% [markdown]
# ### Importing Data

# %%
import requests
import pandas as pd
import io

URL = "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DV0101EN-SkillsNetwork/Data%20Files/Historical_Wildfires.csv"

resp = requests.get(URL)
text = io.StringIO(resp.text)

df = pd.read_csv(text)





print('Data read into a pandas dataframe!')
# Out:
# Data read into a pandas dataframe!

# %%
df.head()
# Out:
#   Region      Date  Estimated_fire_area  Mean_estimated_fire_brightness  \
# 0    NSW  1/4/2005              8.68000                      312.266667
# 1    NSW  1/5/2005             16.61125                      322.475000
# 2    NSW  1/6/2005              5.52000                      325.266667
# 3    NSW  1/7/2005              6.26400                      313.870000
# 4    NSW  1/8/2005              5.40000                      337.383333
#
#    Mean_estimated_fire_radiative_power  Mean_confidence  Std_confidence  \
# 0                            42.400000        78.666667        2.886751
# 1                            62.362500        85.500000        8.088793
# 2                            38.400000        78.333333        3.214550
# 3                            33.800000        92.200000        7.529940
# 4                           122.533333        91.000000        7.937254
#
#    Var_confidence  Count Replaced
# 0        8.333333      3        R
# ...

# %%
#Column names
df.columns
# Out:
# Index(['Region', 'Date', 'Estimated_fire_area',
#        'Mean_estimated_fire_brightness', 'Mean_estimated_fire_radiative_power',
#        'Mean_confidence', 'Std_confidence', 'Var_confidence', 'Count',
#        'Replaced'],
#       dtype='object')

# %%
#data type
df.dtypes
# Out:
# Region                                  object
# Date                                    object
# Estimated_fire_area                    float64
# Mean_estimated_fire_brightness         float64
# Mean_estimated_fire_radiative_power    float64
# Mean_confidence                        float64
# Std_confidence                         float64
# Var_confidence                         float64
# Count                                    int64
# Replaced                                object
# dtype: object

# %%
import datetime as dt

df['Year'] = pd.to_datetime(df['Date']).dt.year
df['Month'] = pd.to_datetime(df['Date']).dt.month

df.dtypes
# Out:
# Region                                  object
# Date                                    object
# Estimated_fire_area                    float64
# Mean_estimated_fire_brightness         float64
# Mean_estimated_fire_radiative_power    float64
# Mean_confidence                        float64
# Std_confidence                         float64
# Var_confidence                         float64
# Count                                    int64
# Replaced                                object
# Year                                     int32
# Month                                    int32
# dtype: object

# %% [markdown]
# ### The change in average estimated fire area over time <br>(use pandas to plot)

# %%
plt.figure(figsize=(12,6))

# Grouping the data by 'Year' and calculating the mean of 'Estimated_fire_area'
df_new = df.groupby('Year')['Estimated_fire_area'].mean()

# Plotting the data
df_new.plot(x=df_new.index, y=df_new.values)
plt.xlabel('Year')
plt.ylabel('Average Estimated Fire Area (km²)')
plt.title('Estimated Fire Area over Time')

plt.show()

# %%
df_new = df.groupby(['Year','Month'])['Estimated_fire_area'].mean()

# Plotting the data

df_new.plot(x=df_new.index, y=df_new.values)
plt.xlabel('Year, Month')
plt.ylabel('Average Estimated Fire Area (km²)')
plt.title('Estimated Fire Area over Time')

plt.show()

# %% [markdown]
# ### The distribution of mean estimated fire brightness across the regions

# %%
df ['Region'].unique()
# Out:
# array(['NSW', 'NT', 'QL', 'SA', 'TA', 'VI', 'WA'], dtype=object)

# %%
plt.figure(figsize=(10,6))

# Using seaborn's barplot function

sns.barplot(data=df, x='Region', y='Mean_estimated_fire_brightness')
plt.xlabel('Region')
plt.ylabel('Mean Estimated Fire Brightness (Kelvin)')
plt.title('Distribution of Mean Estimated Fire Brightness across Regions')

plt.show()

# %% [markdown]
# ### The portion of count of pixels for presumed vegetation fires vary across regions

# %%
plt.figure(figsize=(12, 6))

region_count = df.groupby('Region')['Count'].sum()

plt.pie(region_count, labels=region_count.index)

plt.title('Percentage of Pixels for Presumed Vegetation Fires by Region')
plt.axis('equal')

# Legend with percentages
plt.legend(
    [(i, round(k/region_count.sum()*100, 2)) 
     for i, k in zip(region_count.index, region_count)],
    loc='upper right'
)

plt.show()

# %% [markdown]
# ### Histogram of the mean estimated fire brightness using Matplotlib

# %%
plt.figsize=(10, 6)

plt.hist(x=df['Mean_estimated_fire_brightness'], bins=20)
plt.title('Histogram of the mean estimated fire brightness((Kelvin) ')
plt.ylabel('Count')
plt.xlabel('Mean_estimated_fire_brightness')

plt.show()

# %% [markdown]
# ### the distribution of estimated fire brightness across regions using the functionality of seaborn and pass region as hue

# %%
sns.histplot(data=df, x='Mean_estimated_fire_brightness', hue='Region', multiple='stack')
plt.show()

# %% [markdown]
# ### Correlation between mean Estimated fire radiative power and Mean confidence level

# %%
plt.figure(figsize=(8, 6))
sns.scatterplot(data=df, x='Mean_confidence', y='Mean_estimated_fire_radiative_power')
plt.xlabel('Mean Estimated Fire Radiative Power(MW)')
plt.ylabel('Mean Confidence')
plt.title('Mean Estimated Fire Radiative Power vs. Mean Confidence')
plt.show()

# %% [markdown]
# ### Map of Australia using Folium

# %%
region_data = {'region':['NSW','QL','SA','TA','VI','WA','NT'], 'Lat':[-31.8759835,-22.1646782,-30.5343665,-42.035067,-36.5986096,-25.2303005,-19.491411], 
               'Lon':[147.2869493,144.5844903,135.6301212,146.6366887,144.6780052,121.0187246,132.550964]}
reg=pd.DataFrame(region_data)
reg
# Out:
#   region        Lat         Lon
# 0    NSW -31.875984  147.286949
# 1     QL -22.164678  144.584490
# 2     SA -30.534367  135.630121
# 3     TA -42.035067  146.636689
# 4     VI -36.598610  144.678005
# 5     WA -25.230300  121.018725
# 6     NT -19.491411  132.550964

# %%
aus_reg = folium.map.FeatureGroup()

# Create a Folium map centered on Australia
Aus_map = folium.Map(location=[-25, 135], zoom_start=4)

# loop through the region and add to feature group
for lat, lng, lab in zip(reg.Lat, reg.Lon, reg.region):
    aus_reg.add_child(
        folium.features.CircleMarker(
            [lat, lng],
            popup=lab,
            radius=5, # define how big you want the circle markers to be
            color='red',
            fill=True,
            fill_color='blue',
            fill_opacity=0.6
        )
    )

# add incidents to map
Aus_map.add_child(aus_reg)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
# ...
